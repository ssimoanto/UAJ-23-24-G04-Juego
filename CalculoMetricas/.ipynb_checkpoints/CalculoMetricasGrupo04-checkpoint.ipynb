# %%
import pandas as pd

# %%
jsonFile = pd.read_json("./JSONS/Traza_74ddbf70-0509-4b9e-a22c-befadfca7ee4.json")

# %%
x = pd.json_normalize(jsonFile['data'])
groupedEvents = x.groupby('eventType')
for eid, group in groupedEvents:
    display(group)
    ##display(eid)
# Out:
#    eventType                               IDEvent      timestamp  \
# 0          0  6da9bce9-9836-4599-a15e-9a52dd46ccf2  1713977201493
#
#                                 Session                                  User  \
# 0  74ddbf70-0509-4b9e-a22c-befadfca7ee4  7dfb8ce8-8995-4e6b-8849-ce1828fe5090
#
#                Game  LevelID GameSession  Level  EnemyType  LevelEnd
# 0  SteamMazehemGame      NaN         NaN    NaN        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 55          1  7ef0898c-7bf9-496b-b93e-e54bc62646a7  1713977422093
#
#                                  Session  \
# 55  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID GameSession  Level  \
# 55  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
#
#     EnemyType  LevelEnd
# 55        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 1           2  a7dc8066-b46d-43da-98ed-2adb6d15a6f4  1713977206121
# 26          2  d88fe2e7-63e3-40ad-9d87-af0ec4f2d563  1713977308933
# 43          2  6fac362f-1f78-4a06-a839-6536f26c647e  1713977362508
#
#                                  Session  \
# 1   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 26  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 43  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID GameSession  Level  \
# 1   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 26  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 43  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
#
#     EnemyType  LevelEnd
# 1         NaN       NaN
# 26        NaN       NaN
# 43        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 23          3  49e131ee-35cd-4dc3-bf1e-e1598bbc9a08  1713977301646
# 25          3  a5b589ae-dff9-4d0c-ad89-07acf938be31  1713977301647
# 40          3  01b38fdc-48ed-44fd-b836-00a79274e116  1713977347756
# 42          3  1ba39437-f9ab-48fe-9eb1-1688cf2aa1c0  1713977347756
# 54          3  608a8463-df16-4e45-9c13-b0c82041f1e3  1713977421281
#
#                                  Session  \
# 23  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 25  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 40  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 42  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 54  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID GameSession  Level  \
# 23  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 25  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 40  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 42  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 54  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
#
#     EnemyType  LevelEnd
# 23        NaN       NaN
# 25        NaN       NaN
# 40        NaN       NaN
# 42        NaN       NaN
# 54        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 2           4  f37d28f1-f775-4ffa-a7b8-1891be875b5d  1713977206121
# 8           4  6ded225b-72e2-4bf5-adac-36ace07ad0bc  1713977248259
# 27          4  6a04a6e7-7098-4a84-9ee6-464e5e22043b  1713977308933
# 44          4  60a8d80d-f7b4-4c46-886e-a6a825d8cd0e  1713977362508
# 49          4  ae22b5fe-df2e-41e7-865f-7c4e762a7fd1  1713977397684
#
#                                  Session  \
# 2   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 8   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 27  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 44  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 49  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 2   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 8   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 27  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 44  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 49  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 2   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 8   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 27  5e976e02-48b7-4b43-89ed-8957d6adce1c    NaN        NaN       NaN
# 44  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
# 49  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 7           5  493879ba-0e51-4b10-bdf4-09d2f121c9e0  1713977248259
# 22          5  13dd1dd4-53b0-45d4-af67-e1cb5e0f5661  1713977301646
# 24          5  2517b717-04c8-406a-b8db-b093bd4f3965  1713977301647
# 39          5  b1d32c03-928a-46ac-a19d-2a38e1d9059f  1713977347756
# 41          5  c441f853-ced5-41d8-98fa-ac7cfa441274  1713977347756
# 48          5  563905bb-fe60-4d9d-b1c5-979d51172f4b  1713977397684
# 53          5  805fc012-87c2-489b-b5c3-a6b20b01347a  1713977421280
#
#                                  Session  \
# 7   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 22  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 24  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 39  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 41  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 48  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 53  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 7   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 22  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 24  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 39  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 41  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 48  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 53  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 7   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       0.0
# 22  438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       1.0
# 24  00000000-0000-0000-0000-000000000000    NaN        NaN       2.0
# 39  5e976e02-48b7-4b43-89ed-8957d6adce1c    NaN        NaN       1.0
# 41  00000000-0000-0000-0000-000000000000    NaN        NaN       2.0
# 48  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       0.0
# 53  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       2.0
#     eventType                               IDEvent      timestamp  \
# 50          6  2880c143-467c-4b50-b97f-fedd196eac74  1713977400712
# 52          6  0683986d-772c-4633-9291-0a6cf680335b  1713977420070
#
#                                  Session  \
# 50  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 52  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID GameSession  Level  \
# 50  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
# 52  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
#
#     EnemyType  LevelEnd
# 50        NaN       NaN
# 52        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 51          7  60550d2f-9b51-45e5-aac0-ba59cecc2fcf  1713977404140
#
#                                  Session  \
# 51  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID GameSession  Level  \
# 51  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN         NaN    NaN
#
#     EnemyType  LevelEnd
# 51        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 6          10  97e4e4b2-97f4-4959-9420-62ce71447f24  1713977245920
# 9          10  937dfa6e-d1ee-45ce-95e7-283ace1d66f8  1713977276025
# 10         10  ad3a949d-e413-409a-9029-41ff7d15b8b1  1713977278382
# 11         10  700b9eda-cf6f-40ef-a0c4-9523be198771  1713977283486
# 12         10  ec90024d-6651-4ce9-94dc-4b370940e42c  1713977285502
# 13         10  24c54ba4-c778-4c47-98bf-159e780b2737  1713977287524
# 14         10  cdffd9e6-dc18-4cc8-8c66-7c8f7abf0dbd  1713977289544
# 15         10  600fe010-b807-4e87-a3a5-325b4e56c331  1713977292726
# 16         10  de2d2004-b83f-411f-961b-02c484f0f1ae  1713977293562
# 17         10  152ee2d7-7f26-4363-be48-a2052177a3ea  1713977295583
# 18         10  060cdbbf-23c3-4c5b-b557-d257581274f4  1713977297604
# 19         10  4afec5df-44c2-4187-937b-135d44ed9f5c  1713977299626
# 20         10  2f869f2d-19be-4470-af94-029e7acf609e  1713977301646
# 31         10  93d53889-8bc1-4534-a117-2e5e20cbf17e  1713977332395
# 32         10  0c0d0a83-7b17-42dd-b080-93315ea74eed  1713977334958
# 33         10  57b9825d-8501-41f1-8242-3853e588770c  1713977337519
# 34         10  026209a4-5b8b-4e33-aa42-4ecc7197a47a  1713977340079
# 35         10  632b722a-4c5f-411a-b8f8-684f1fad273f  1713977342639
# 36         10  b463bb24-4b16-40d3-8ff0-a9db91bce7ac  1713977345195
# 37         10  e593ad0a-cd8d-4640-b1da-a392b46aac51  1713977347756
#
#                                  Session  \
# 6   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 9   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 10  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 11  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 12  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 13  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 14  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 15  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 16  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 17  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 18  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 19  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 20  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 31  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 32  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 33  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 34  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 35  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 36  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 37  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 6   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 9   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 10  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 11  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 12  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 13  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 14  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 15  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 16  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 17  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 18  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 19  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 20  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 31  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 32  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 33  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 34  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 35  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 36  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 37  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
#
#                              GameSession  Level  EnemyType  LevelEnd
# 6   438615aa-e3a2-4a47-91ff-834f32162480    1.0        2.0       NaN
# 9   438615aa-e3a2-4a47-91ff-834f32162480    2.0        2.0       NaN
# 10  438615aa-e3a2-4a47-91ff-834f32162480    2.0        1.0       NaN
# 11  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 12  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 13  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 14  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 15  438615aa-e3a2-4a47-91ff-834f32162480    2.0        2.0       NaN
# 16  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 17  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 18  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 19  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 20  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 31  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 32  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 33  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 34  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 35  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 36  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 37  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
#     eventType                               IDEvent      timestamp  \
# 21         11  7fcb415f-36be-4cf2-a768-7fee517e557e  1713977301646
# 38         11  222f357e-af2f-4db9-9baa-7c006c54eb61  1713977347756
#
#                                  Session  \
# 21  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 38  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 21  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 38  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
#
#                              GameSession  Level  EnemyType  LevelEnd
# 21  438615aa-e3a2-4a47-91ff-834f32162480    2.0        NaN       NaN
# 38  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 3          12  0ddbb34d-975c-41a6-97b1-2fa60a5e8c66  1713977233255
# 4          12  2ec56b1e-a388-4832-9a41-30266f63459f  1713977236752
# 5          12  7702a9d5-9ea6-4e1e-84e7-52cc3775c6d9  1713977237160
# 28         12  8d05c414-788a-479d-b9dc-ab989d548d14  1713977329054
# 29         12  3293ab68-adfe-40b6-8442-b7c0d74cd5db  1713977329608
# 30         12  38fafb22-cbb0-461c-a853-1c35207cf012  1713977330208
# 45         12  f0c93fd8-4639-4b9a-aa65-58af0674e17b  1713977384952
# 46         12  bb62509a-bbaa-4448-9306-1b18af5c1bef  1713977389038
# 47         12  0d5707aa-580b-4ace-9039-054e16e0e608  1713977389808
#
#                                  Session  \
# 3   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 4   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 5   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 28  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 29  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 30  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 45  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 46  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 47  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 3   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 4   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 5   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 28  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 29  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 30  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 45  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 46  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 47  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
#
#                              GameSession  Level  EnemyType  LevelEnd
# 3   438615aa-e3a2-4a47-91ff-834f32162480    1.0        NaN       NaN
# 4   438615aa-e3a2-4a47-91ff-834f32162480    1.0        NaN       NaN
# 5   438615aa-e3a2-4a47-91ff-834f32162480    1.0        NaN       NaN
# 28  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        NaN       NaN
# 29  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        NaN       NaN
# 30  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        NaN       NaN
# 45  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    1.0        NaN       NaN
# 46  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    1.0        NaN       NaN
# 47  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    1.0        NaN       NaN

# %% [markdown]
# ### Los eventos y sus ID:
# - SessionStart = 0
# - SessionStop = 1
# - GameStart = 2
# - GameEnd = 3
# - LevelStart = 4
# - LevelEnd = 5
# - Pause = 6
# - Resume = 7
# - //
# - Attack = 8
# - EnemyReceive = 9
# - PlayerReceive = 10
# - PlayerDead = 11
# - RoomMove = 12

# %% [markdown]
# # Métrica 1: Tiempo de finalización de nivel
# ¿El jugador tarda demasiado tiempo en completar cada uno de los dos niveles?

# %%
from datetime import datetime

## estoy usando los de la sesion por ahora, pero se haria con los de cada nivel.
startEvent = groupedEvents.get_group(4)
display(startEvent)
endEvent = groupedEvents.get_group(5)
display(endEvent)
     
##a = startEvent.get("timestamp").values[0]
##b = endEvent.get("timestamp").values[0]


##a_seconds = a / 1000
##b_seconds = b / 1000
##print("Total: ")
##print((b_seconds - a_seconds), " segundos")

##dt_object_start = datetime.fromtimestamp(a_seconds)
##dt_object_end = datetime.fromtimestamp(b_seconds)

##print("Start time: ", dt_object_start)
##print("End time: ", dt_object_end)

endEvent_filtered = endEvent[endEvent['LevelEnd'] == 0]

# Comparar los eventos filtrados con startEvent
startEvent_filtered = startEvent[startEvent['LevelID'].isin(endEvent_filtered['LevelID']) & startEvent['GameSession'].isin(endEvent_filtered['GameSession'])]


print("Eventos de inicio (startEvent) después de filtrar por causa 0 en endEvent:\n")
display(startEvent_filtered)

print("Eventos de fin (endEvent) después de filtrar por causa 0 en endEvent:\n")
display(endEvent_filtered)
if len(startEvent) < len(endEvent):
    endEvent = endEvent.drop(endEvent.index[len(endEvent) - 1])

for a in range(len(startEvent)-1, -1, -1):
    if endEvent.iloc[a]["LevelEnd"] == 1:
        endEvent = endEvent.drop(endEvent.index[a])
        startEvent = startEvent.drop(startEvent.index[a])
    elif endEvent.iloc[a]["LevelEnd"] == 2:
        endEvent = endEvent.drop(endEvent.index[a])

if len(startEvent) > 0:        
    print("Niveles validos:")
    display(startEvent)
    display(endEvent)
    
    total_pause_time = 0
    
    if 6 in groupedEvents.groups and 7 in groupedEvents.groups:

        pauseEvents = groupedEvents.get_group(6)
        resumeEvents = groupedEvents.get_group(7)

        for i in range(len(resumeEvents)):
            pause_time = pauseEvents.iloc[i]["timestamp"]
            resume_time = resumeEvents.iloc[i]["timestamp"]

            total_pause_time += resume_time - pause_time

    
    total_pause_time_seconds = total_pause_time / 1000

    
    session_duration = (b_seconds - a_seconds) - total_pause_time_seconds

    print("Duración de la sesión con pausas descontadas: ", session_duration/60, " minutos")

else:
    print("Error: no hay niveles válidos para analizar")
# Out:
#     eventType                               IDEvent      timestamp  \
# 2           4  f37d28f1-f775-4ffa-a7b8-1891be875b5d  1713977206121
# 8           4  6ded225b-72e2-4bf5-adac-36ace07ad0bc  1713977248259
# 27          4  6a04a6e7-7098-4a84-9ee6-464e5e22043b  1713977308933
# 44          4  60a8d80d-f7b4-4c46-886e-a6a825d8cd0e  1713977362508
# 49          4  ae22b5fe-df2e-41e7-865f-7c4e762a7fd1  1713977397684
#
#                                  Session  \
# 2   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 8   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 27  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 44  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 49  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 2   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 8   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 27  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 44  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 49  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 2   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 8   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 27  5e976e02-48b7-4b43-89ed-8957d6adce1c    NaN        NaN       NaN
# 44  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
# 49  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 7           5  493879ba-0e51-4b10-bdf4-09d2f121c9e0  1713977248259
# 22          5  13dd1dd4-53b0-45d4-af67-e1cb5e0f5661  1713977301646
# 24          5  2517b717-04c8-406a-b8db-b093bd4f3965  1713977301647
# 39          5  b1d32c03-928a-46ac-a19d-2a38e1d9059f  1713977347756
# 41          5  c441f853-ced5-41d8-98fa-ac7cfa441274  1713977347756
# 48          5  563905bb-fe60-4d9d-b1c5-979d51172f4b  1713977397684
# 53          5  805fc012-87c2-489b-b5c3-a6b20b01347a  1713977421280
#
#                                  Session  \
# 7   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 22  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 24  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 39  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 41  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 48  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 53  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 7   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 22  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 24  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
# 39  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 41  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 48  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 53  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 7   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       0.0
# 22  438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       1.0
# 24  00000000-0000-0000-0000-000000000000    NaN        NaN       2.0
# 39  5e976e02-48b7-4b43-89ed-8957d6adce1c    NaN        NaN       1.0
# 41  00000000-0000-0000-0000-000000000000    NaN        NaN       2.0
# 48  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       0.0
# 53  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       2.0
# Eventos de inicio (startEvent) después de filtrar por causa 0 en endEvent:
#     eventType                               IDEvent      timestamp  \
# 2           4  f37d28f1-f775-4ffa-a7b8-1891be875b5d  1713977206121
# 44          4  60a8d80d-f7b4-4c46-886e-a6a825d8cd0e  1713977362508
#
#                                  Session  \
# 2   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 44  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 2   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 44  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 2   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 44  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
# Eventos de fin (endEvent) después de filtrar por causa 0 en endEvent:
#     eventType                               IDEvent      timestamp  \
# 7           5  493879ba-0e51-4b10-bdf4-09d2f121c9e0  1713977248259
# 48          5  563905bb-fe60-4d9d-b1c5-979d51172f4b  1713977397684
#
#                                  Session  \
# 7   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 48  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 7   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 48  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 7   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       0.0
# 48  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       0.0
# Niveles validos:
#     eventType                               IDEvent      timestamp  \
# 2           4  f37d28f1-f775-4ffa-a7b8-1891be875b5d  1713977206121
# 27          4  6a04a6e7-7098-4a84-9ee6-464e5e22043b  1713977308933
# 49          4  ae22b5fe-df2e-41e7-865f-7c4e762a7fd1  1713977397684
#
#                                  Session  \
# 2   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 27  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 49  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 2   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 27  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 49  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      2.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 2   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       NaN
# 27  5e976e02-48b7-4b43-89ed-8957d6adce1c    NaN        NaN       NaN
# 49  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       NaN
#     eventType                               IDEvent      timestamp  \
# 7           5  493879ba-0e51-4b10-bdf4-09d2f121c9e0  1713977248259
# 48          5  563905bb-fe60-4d9d-b1c5-979d51172f4b  1713977397684
#
#                                  Session  \
# 7   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 48  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 7   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
# 48  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      1.0
#
#                              GameSession  Level  EnemyType  LevelEnd
# 7   438615aa-e3a2-4a47-91ff-834f32162480    NaN        NaN       0.0
# 48  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    NaN        NaN       0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 67
#      61             total_pause_time += resume_time - pause_time
#      64     total_pause_time_seconds = total_pause_time / 1000
# ---> 67     session_duration = (b_seconds - a_seconds) - total_pause_time_seconds
#      69     print("Duración de la sesión con pausas descontadas: ", session_duration/60, " minutos")
#      71 else:
#
# NameError: name 'b_seconds' is not defined

# %% [markdown]
# # Métrica 2: Cantidad de movimientos por nivel
# ¿El jugador usa demasiados movimientos de salas en cada uno de los dos niveles?

# %%
#Eventos de movimiento de sala
room_moves = groupedEvents.get_group(12)

#Agrupar los movimientos por sesión y nivel
movements = room_moves.groupby(['GameSession', 'Level']).size().reset_index(name='Movements')

#Obtener las sesiones únicas de los eventos de fin
endEventSessions = endEvent_filtered['GameSession'].unique()

#Filtrar los movimientos que pertenecen a una sesión de juego completada
completed_movements = movements[movements['GameSession'].isin(endEventSessions)]

#LevelIDs de los eventos completados
completed_levels = endEvent_filtered[endEvent_filtered['LevelEnd'] == 0]['LevelID'].unique()

print("Movimientos de sesión completados por niveles:\n")
display(completed_movements)

#Level 1
filtered_movements_1 = completed_movements[completed_movements['Level'] == 1.0]

mean_movements_1 = filtered_movements_1['Movements'].mean()

#Level 2
filtered_movements_0 = completed_movements[completed_movements['Level'] == 2.0]

mean_movements_0 = filtered_movements_0['Movements'].mean()

print(f"La media de movimientos de sala para el nivel 1 es: {mean_movements_1}")
print(f"La media de 'Movements' para las filas donde 'Level' es 2.0 es: {mean_movements_0}")
# Out:
# Movimientos de sesión completados por niveles:
#                             GameSession  Level  Movements
# 0  438615aa-e3a2-4a47-91ff-834f32162480    1.0          3
# 2  98e1614a-bcce-49d0-aab2-dbe1d790d3d4    1.0          3
# La media de 'Movements' para las filas donde 'Level' es 1.0 es: 3.0
# La media de 'Movements' para las filas donde 'Level' es 2.0 es: nan

# %% [markdown]
# # Métrica 3: Precisión de golpes a los enemigos
# ¿El jugador falla significativamente más ataques en el nivel 2 que en el nivel 1?

# %%
# FALTA AGRUPAR POR NIVELES
# Verificar si los grupos existen antes de acceder a ellos
if 8 in groupedEvents.groups:
    attack = groupedEvents.get_group(8)
    enemy_receive = groupedEvents.get_group(9) if 9 in groupedEvents.groups else None
    
    display(attack)
    display(enemy_receive)

    # Se agrupan los ataques realizados y los recibidos por los enemigos y se cuenta el número de cada uno
    attack_count = attack.groupby('Session').size().reset_index(name='Total Attacks')
    
    # Si el grupo 9 existe, contamos los aciertos; de lo contrario, asumimos que son 0
    if enemy_receive is not None:
        hit_count = enemy_receive.groupby('Session').size().reset_index(name='Total Hits')
    else:
        hit_count = pd.DataFrame({'Session': attack_count['Session'], 'Total Hits': 0})
    
    # Agrupar los datos en un único dataframe
    accuracy = pd.merge(attack_count, hit_count, on='Session', how='left')
    accuracy['Total Hits'] = accuracy['Total Hits'].fillna(0)

    # Calcular la precisión de los golpes
    accuracy['Accuracy'] = (accuracy['Total Hits'] / accuracy['Total Attacks']) * 100
    accuracy['Accuracy'] = accuracy['Accuracy'].apply(lambda x: f"{x:.3f}%")

    print("Hit accuracy:\n")
    print(accuracy[['Session', 'Accuracy']].to_string(index=False))
else:
    print("El grupo 8 no existe en el DataFrame 'groupedEvents'. No se pueden calcular las estadísticas.")
# Out:
# El grupo 8 no existe en el DataFrame 'groupedEvents'. No se pueden calcular las estadísticas.

# %% [markdown]
# # Métrica 4: Impactos de los elementos dañinos
# ¿Es coherente la variación del daño provocado por cada elemento dañino a lo largo de los dos niveles?

# %%
# FALTA AGRUPAR POR NIVELES
player_receive = groupedEvents.get_group(10)
display(player_receive)

# Se agrupan los impactos por sesión y tipo de enemigo y se cuenta el número de cada una
impact_count = player_receive.groupby(['Session', 'EnemyType']).size().reset_index(name='Impacts')

# Impactos totales por sesión
total_impact_count = player_receive.groupby('Session').size().reset_index(name='Total Impacts')

# Agrupar los datos en un único dataframe
impact_count = impact_count.merge(total_impact_count, on='Session', how='left')

# Calcular el porcentaje de impactos provocados por cada tipo de enemigo
impact_count['Enemy Percentage'] = (impact_count['Impacts'] / impact_count['Total Impacts']) * 100
impact_count['Enemy Percentage'].fillna(0, inplace=True)
impact_count['Enemy Percentage'] = impact_count['Enemy Percentage'].apply(lambda x: f"{x:.3f}%")

print("Enemy impacts:\n")
print(impact_count[['Session', 'EnemyType', 'Impacts', 'Enemy Percentage']].to_string(index=False))
print("\nTotal impacts: ", impact_count['Impacts'].sum())
# Out:
#     eventType                               IDEvent      timestamp  \
# 6          10  97e4e4b2-97f4-4959-9420-62ce71447f24  1713977245920
# 9          10  937dfa6e-d1ee-45ce-95e7-283ace1d66f8  1713977276025
# 10         10  ad3a949d-e413-409a-9029-41ff7d15b8b1  1713977278382
# 11         10  700b9eda-cf6f-40ef-a0c4-9523be198771  1713977283486
# 12         10  ec90024d-6651-4ce9-94dc-4b370940e42c  1713977285502
# 13         10  24c54ba4-c778-4c47-98bf-159e780b2737  1713977287524
# 14         10  cdffd9e6-dc18-4cc8-8c66-7c8f7abf0dbd  1713977289544
# 15         10  600fe010-b807-4e87-a3a5-325b4e56c331  1713977292726
# 16         10  de2d2004-b83f-411f-961b-02c484f0f1ae  1713977293562
# 17         10  152ee2d7-7f26-4363-be48-a2052177a3ea  1713977295583
# 18         10  060cdbbf-23c3-4c5b-b557-d257581274f4  1713977297604
# 19         10  4afec5df-44c2-4187-937b-135d44ed9f5c  1713977299626
# 20         10  2f869f2d-19be-4470-af94-029e7acf609e  1713977301646
# 31         10  93d53889-8bc1-4534-a117-2e5e20cbf17e  1713977332395
# 32         10  0c0d0a83-7b17-42dd-b080-93315ea74eed  1713977334958
# 33         10  57b9825d-8501-41f1-8242-3853e588770c  1713977337519
# 34         10  026209a4-5b8b-4e33-aa42-4ecc7197a47a  1713977340079
# 35         10  632b722a-4c5f-411a-b8f8-684f1fad273f  1713977342639
# 36         10  b463bb24-4b16-40d3-8ff0-a9db91bce7ac  1713977345195
# 37         10  e593ad0a-cd8d-4640-b1da-a392b46aac51  1713977347756
#
#                                  Session  \
# 6   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 9   74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 10  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 11  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 12  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 13  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 14  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 15  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 16  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 17  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 18  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 19  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 20  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 31  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 32  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 33  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 34  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 35  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 36  74ddbf70-0509-4b9e-a22c-befadfca7ee4
# 37  74ddbf70-0509-4b9e-a22c-befadfca7ee4
#
#                                     User Game  LevelID  \
# 6   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 9   7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 10  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 11  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 12  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 13  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 14  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 15  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 16  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 17  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 18  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 19  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 20  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 31  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 32  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 33  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 34  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 35  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 36  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
# 37  7dfb8ce8-8995-4e6b-8849-ce1828fe5090  NaN      NaN
#
#                              GameSession  Level  EnemyType  LevelEnd
# 6   438615aa-e3a2-4a47-91ff-834f32162480    1.0        2.0       NaN
# 9   438615aa-e3a2-4a47-91ff-834f32162480    2.0        2.0       NaN
# 10  438615aa-e3a2-4a47-91ff-834f32162480    2.0        1.0       NaN
# 11  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 12  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 13  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 14  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 15  438615aa-e3a2-4a47-91ff-834f32162480    2.0        2.0       NaN
# 16  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 17  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 18  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 19  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 20  438615aa-e3a2-4a47-91ff-834f32162480    2.0        3.0       NaN
# 31  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 32  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 33  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 34  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 35  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 36  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# 37  5e976e02-48b7-4b43-89ed-8957d6adce1c    1.0        2.0       NaN
# Enemy impacts:
#
#                              Session  EnemyType  Impacts Enemy Percentage
# 74ddbf70-0509-4b9e-a22c-befadfca7ee4        1.0        1           5.000%
# 74ddbf70-0509-4b9e-a22c-befadfca7ee4        2.0       10          50.000%
# 74ddbf70-0509-4b9e-a22c-befadfca7ee4        3.0        9          45.000%
#
# Total impacts:  20
